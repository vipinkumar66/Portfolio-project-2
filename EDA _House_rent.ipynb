# %% [markdown]
# # About Dataset
#
#
# THIS DATA HAS BEEN TAKEN FROM THE KAGGLE.
# In this Dataset, we have information on almost 4700+ Houses/Apartments/Flats Available for Rent with different parameters like BHK, Rent, Size, No. of Floors, Area Type, Area Locality, City, Furnishing Status, Type of Tenant Preferred, No. of Bathrooms, Point of Contact

# %% [markdown]
# BHK: Number of Bedrooms, Hall, Kitchen.
#
# Rent: Rent of the Houses/Apartments/Flats.
#
# Size: Size of the Houses/Apartments/Flats in Square Feet.
#
# Floor: Houses/Apartments/Flats situated in which Floor and Total Number of Floors (Example: Ground out of 2, 3 out of 5, etc.)
#
# Area Type: Size of the Houses/Apartments/Flats calculated on either Super Area or Carpet Area or Build Area.
#
# Area Locality: Locality of the Houses/Apartments/Flats.
#
# City: City where the Houses/Apartments/Flats are Located.
#
# Furnishing Status: Furnishing Status of the Houses/Apartments/Flats, either it is Furnished or Semi-Furnished or Unfurnished.
#
# Tenant Preferred: Type of Tenant Preferred by the Owner or Agent.
#
# Bathroom: Number of Bathrooms.
#
# Point of Contact: Whom should you contact for more information regarding the Houses/Apartments/Flats.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS

# %%
df = pd.read_csv(r'D:\Vipin Data\Drive g\DO YOU HAVE IT IN YOU\python homework\House_Rent_Dataset.csv')

# %%
df
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1     2022-05-13    2  20000   800       1 out of 3   Super Area
# 2     2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3     2022-07-04    2  10000   800       1 out of 2   Super Area
# 4     2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
df.tail()
# Out:
#        Posted On  BHK   Rent  Size         Floor    Area Type  \
# 4741  2022-05-18    2  15000  1000    3 out of 5  Carpet Area
# 4742  2022-05-15    3  29000  2000    1 out of 4   Super Area
# 4743  2022-07-10    3  35000  1750    3 out of 5  Carpet Area
# 4744  2022-07-06    3  45000  1500  23 out of 34  Carpet Area
# 4745  2022-05-04    2  15000  1000    4 out of 5  Carpet Area
#
#              Area Locality       City Furnishing Status  Tenant Preferred  \
# 4741          Bandam Kommu  Hyderabad    Semi-Furnished  Bachelors/Family
# 4742  Manikonda, Hyderabad  Hyderabad    Semi-Furnished  Bachelors/Family
# 4743  Himayath Nagar, NH 7  Hyderabad    Semi-Furnished  Bachelors/Family
# 4744            Gachibowli  Hyderabad    Semi-Furnished            Family
# 4745       Suchitra Circle  Hyderabad       Unfurnished         Bachelors
#
#       Bathroom Point of Contact
# 4741         2    Contact Owner
# 4742         3    Contact Owner
# 4743         3    Contact Agent
# ...

# %%
df.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %%
df.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %% [markdown]
# # Top 5 and lowest 5 rent prices

# %%
Top_5rent= df['Rent'].sort_values(ascending=False).head()

# %%
Top_5rent
# Out:
# 1837    3500000
# 1001    1200000
# 827     1000000
# 1329     850000
# 1459     700000
# Name: Rent, dtype: int64

# %%
Lowest_5rent = df['Rent'].sort_values(ascending=False).tail()

# %%
Lowest_5rent
# Out:
# 146     2200
# 2475    2000
# 471     1800
# 285     1500
# 4076    1200
# Name: Rent, dtype: int64

# %% [markdown]
# # Mean, median, ,max and min of Rent for different cities

# %%
city= df.groupby('City')

# %%
city['Rent'].median().sort_values(ascending=False)
# Out:
# City
# Mumbai       52000.0
# Delhi        17000.0
# Bangalore    14000.0
# Chennai      14000.0
# Hyderabad    14000.0
# Kolkata       8500.0
# Name: Rent, dtype: float64

# %%
round(city['Rent'].mean()).sort_values(ascending=False)
# Out:
# City
# Mumbai       85321.0
# Delhi        29462.0
# Bangalore    24966.0
# Chennai      21614.0
# Hyderabad    20555.0
# Kolkata      11645.0
# Name: Rent, dtype: float64

# %%
city['Rent'].max().sort_values(ascending=False)
# Out:
# City
# Bangalore    3500000
# Mumbai       1200000
# Chennai       600000
# Delhi         530000
# Hyderabad     400000
# Kolkata       180000
# Name: Rent, dtype: int64

# %%
city['Rent'].min().sort_values(ascending=False)
# Out:
# City
# Mumbai       4500
# Bangalore    3500
# Chennai      3000
# Delhi        2000
# Kolkata      1500
# Hyderabad    1200
# Name: Rent, dtype: int64

# %% [markdown]
# # Distribution with respect to cities

# %%
cities= df['City'].value_counts()

# %%
cities
# Out:
# Mumbai       972
# Chennai      891
# Bangalore    886
# Hyderabad    868
# Delhi        605
# Kolkata      524
# Name: City, dtype: int64

# %%
plt.figure(figsize=(10,8))
explode= (0.1,0,0,0,0,0)
plt.pie(cities.values, labels=cities.index, autopct='%1.1f%%', shadow = True, frame = True, explode=explode, wedgeprops={'edgecolor':'black'})
plt.legend()
plt.axis('equal')
plt.title('Relative share of employees by company size')
plt.show()

# %% [markdown]
# # Different type of tenant prefered by the people with respect to area

# %%
plt.figure(figsize=(8,4), dpi=200)
ax= sns.countplot(data=df, x='Area Type', hue='Tenant Preferred')
for i in ax.containers:
    ax.bar_label(i,)

# %% [markdown]
# Confirmation whether the values given are correct or not?

# %%
x= df.groupby('Tenant Preferred')

# %%
x['Area Type'].value_counts()
# Out:
# Tenant Preferred  Area Type
# Bachelors         Carpet Area     691
#                   Super Area      139
# Bachelors/Family  Super Area     2161
#                   Carpet Area    1281
#                   Built Area        2
# Family            Carpet Area     326
#                   Super Area      146
# Name: Area Type, dtype: int64

# %% [markdown]
# # Furnishing status prefered by the people with respect to city

# %%
plt.figure(figsize=(8,4), dpi=200)
ax= sns.countplot(data=df, x='Furnishing Status', hue='City')
for i in ax.containers:
    ax.bar_label(i,)

# %% [markdown]
# # Distribution of the Bathrooms

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,6), dpi=200)
ax= sns.countplot(x='Bathroom', data=df)
for i in ax.containers:
    ax.bar_label(i)

# %% [markdown]
# # Distribution of the BHK

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(10,6), dpi=200)
ax= sns.countplot(x='BHK', data=df)
for i in ax.containers:
    ax.bar_label(i)

# %% [markdown]
# # Correlation Graphs

# %%
plt.figure(figsize=(8,4), dpi=200)
sns.scatterplot(x= 'Size', y='Rent', hue='Rent', data=df)
# Out:
# <AxesSubplot:xlabel='Size', ylabel='Rent'>

# %%
plt.figure(figsize=(6,4), dpi=200)
sns.regplot(x='Size', y='Rent', scatter_kws={'color':'red'}, line_kws={'color':'blue'}, data=df)
# Out:
# <AxesSubplot:xlabel='Size', ylabel='Rent'>

# %% [markdown]
# Size and rent have moderate correlation between each other.

# %% [markdown]
# # Correlation using the heat map

# %%
df.corr()
# Out:
#                BHK      Rent      Size  Bathroom
# BHK       1.000000  0.369718  0.716145  0.794885
# Rent      0.369718  1.000000  0.413551  0.441215
# Size      0.716145  0.413551  1.000000  0.740703
# Bathroom  0.794885  0.441215  0.740703  1.000000

# %%
correlation_matrix= df.corr()
plt.figure(figsize=(6,4), dpi=200)
sns.heatmap(correlation_matrix, annot=True)
plt.title('correlation matrix for BHK, Rent, Size, Bathroom')
# Out:
# Text(0.5, 1.0, 'correlation matrix for BHK, Rent, Size, Bathroom')

# %% [markdown]
# # Histogram for Size

# %%
plt.figure(figsize=(10,6), dpi=200)
sns.set(style='darkgrid')
sns.displot(x='Size', data=df, bins=40, color='blue', edgecolor='red', kde=True)

# %% [markdown]
# # Pivot table

# %%
pd.pivot_table(index='City', values='Rent', columns='BHK', aggfunc='mean', data=df, fill_value=0)
# Out:
# BHK                   1             2              3              4  \
# City
# Bangalore   9368.333333  16122.041763   61988.580247  113043.478261
# Chennai     8455.926380  15701.692149   35741.913636   96350.000000
# Delhi      11332.500000  18878.342520   44141.558442  117455.583333
# Hyderabad   9753.793103  13877.652466   29337.650206   95730.769231
# Kolkata     6897.183099  10687.847826   19666.576087   26909.090909
# Mumbai     29218.843206  57768.195187  122009.242291  279109.589041
#
# BHK                    5       6
# City
# Bangalore       0.000000       0
# Chennai     75000.000000  170000
# Delhi      190000.000000       0
# Hyderabad  131666.666667   45000
# Kolkata     23750.000000   20000
# Mumbai     442727.272727       0

# %% [markdown]
# # Wordcloud

# %%
text= ''.join(areaa for areaa in df['Area Locality'])
plt.figure(figsize=(16,8), dpi=200)
word_cloud=WordCloud(width= 1400, height=700, background_color= 'black' ).generate(text)
plt.imshow(word_cloud, interpolation="gaussian")
plt.axis("off")
plt.show()

# %% [markdown]
# # THANK YOU
